# %% [markdown]
# # Artificial Intelligence: A Modern Approach
#
# **Student workspace** · Russell & Norvig (4e)
#
# Use the **Jupyter Slide Show** toolbar on this notebook to set each cell’s slide type (*Slide*, *Sub-slide*, *Fragment*, …), then present from the command palette or notebook UI.

# %% [markdown]
# ## Where everything lives
#
# | What | Where |
# |------|--------|
# | **Jupyter Book** (read + Thebe) | Port **8765** after build — open from **Ports** |
# | **JupyterLab** | Port **8888**, token `aima` |
# | **Exercise answers** | `exercises/chNN/ex_*.md` |
# | **Regenerate book pages** | `npm run docs:generate` then `npm run book:build` |

# %% [markdown]
# ### Optional: export to Reveal slides
#
# From a terminal with the repo `.venv` active:
#
# ```bash
# .venv/bin/jupyter nbconvert slides/AIMA-course.ipynb --to slides --post serve
# ```
#
# For day-to-day work, presenting **inside VS Code** from this notebook is enough.

# %%
# Demo code cell (run in JupyterLab or an interactive window)
print("Hello from the AIMA Codespace")
